# %%
import pandas as pd

# =============================================================================
# DATA LOADING
# =============================================================================

df = pd.read_csv(
    "data/dvf/R44_Grand_Est/DVF_PLUS_2025_2_CSV_R044_ED251/1_DONNEES_LIVRAISON/dvf_plus.csv", 
    sep='|', 
    na_values=''
)

# %%
pd.set_option('display.max_rows', None)

df.head(10).T
# Out:
#                                            0  \
# idmutation                           1831887
# idmutinvar  ee51050b17750a02692492205a4ed7f3
# idopendata  ee51050b17750a02692492205a4ed7f3
# idnatmut                                   1
# codservch                                NaN
# refdoc                                   NaN
# datemut                           2015-06-25
# anneemut                                2015
# moismut                                    6
# coddep                                     8
# libnatmut                              Vente
# nbartcgi                                   0
# l_artcgi                                 NaN
# vefa                                   False
# valeurfonc                           55000.0
# nbdispo                                    1
# nblot                                    1.0
# nbcomm                                     1
# l_codinsee                             08409
# nbsection                                  1
# ...

# %%
df.isna().all()
# Out:
# idmutation    False
# idmutinvar    False
# idopendata    False
# idnatmut      False
# codservch      True
# refdoc         True
# datemut       False
# anneemut      False
# moismut       False
# coddep        False
# libnatmut     False
# nbartcgi      False
# l_artcgi       True
# vefa          False
# valeurfonc    False
# nbdispo       False
# nblot         False
# nbcomm        False
# l_codinsee    False
# nbsection     False
# l_section     False
# nbpar         False
# l_idpar       False
# nbparmut      False
# l_idparmut    False
# nbsuf         False
# sterr         False
# l_dcnt        False
# nbvolmut      False
# nblocmut      False
# l_idlocmut    False
# nblocmai      False
# nblocapt      False
# nblocdep      False
# nblocact      False
# nbapt1pp      False
# nbapt2pp      False
# nbapt3pp      False
# nbapt4pp      False
# nbapt5pp      False
# nbmai1pp      False
# nbmai2pp      False
# nbmai3pp      False
# nbmai4pp      False
# nbmai5pp      False
# ...

# %%
df = df.drop(columns = [
    'codservch', 
    'refdoc',
    'l_artcgi',
    'isOriginalTitle',
    'types',
    'region'
    ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df1 = df.drop(columns = [
#       2     'attributes',
#       3     'language',
#       4     'ordering',
#       5     'isOriginalTitle',
#       6     'types',
#       7     'region'
#       8     ])
#
# File /opt/anaconda3/envs/wcs-data-analyst-2025/lib/python3.11/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
# ...
